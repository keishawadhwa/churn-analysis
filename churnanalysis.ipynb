# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Downloads/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [raw]
# replacing blanks with 0 as tenure is 0 and no total charges are recorded

# %%
df["TotalCharges"] = df["TotalCharges"].replace(" ","0")
df["TotalCharges"] = df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "no"

df["SeniorCitizen"]=df["SeniorCitizen"].apply(conv)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
# 2  3668-QPYBK    Male            no      No         No       2          Yes
# 3  7795-CFOCW    Male            no      No         No      45           No
# 4  9237-HQITU  Female            no      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
ax= sns.countplot(x = "Churn" , data = df)
ax.bar_label(ax.containers[0])
plt.title("Count of Customer by Churn") 
plt.show()

# %%
plt.figure(figsize=(3,4))
gb = df.groupby("Churn").agg({'Churn':'count'})
plt.pie(gb["Churn"],labels=gb.index,autopct="%1.2f%%")
plt.title("Percentage of Churned Customers")
plt.show()

# %% [markdown]
# #from the given piechart we can conclude that 26.54% of our customers have churned out
# #now lets explore the reason

# %%
ax=sns.countplot(x = "gender",data=df,hue="Churn",color=colors[idx])
ax.bar_label(ax.containers[0])
plt.title("Churn by Gender")
plt.show()
# Out:
# C:\Users\wadhw\AppData\Local\Temp\ipykernel_27160\814326456.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   ax=sns.countplot(x = "gender",data=df,hue="Churn",color=colors[idx])

# %%
colors = ['skyblue', 'salmon']
ax=sns.countplot(x = "SeniorCitizen",data=df,hue="Churn",color=colors[idx])
ax.bar_label(ax.containers[0])
plt.title("Churn by Senior Citizen")
plt.show()
# Out:
# C:\Users\wadhw\AppData\Local\Temp\ipykernel_27160\1500544126.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   ax=sns.countplot(x = "SeniorCitizen",data=df,hue="Churn",color=colors[idx])

# %%
grouped = df.groupby(['SeniorCitizen', 'Churn']).size().unstack(fill_value=0)
percentages = grouped.div(grouped.sum(axis=1), axis=0) * 100
fig, ax = plt.subplots(figsize=(8,6))
bottom = None
colors = ['skyblue', 'salmon']  
for idx, churn_status in enumerate(percentages.columns):
    ax.bar(percentages.index, percentages[churn_status],
           bottom=bottom,
           label=f'{churn_status}',
           color=colors[idx])
    for i, value in enumerate(percentages[churn_status]):
        total_height = value if bottom is None else bottom[i] + value
        ax.text(i, total_height - value/2, f'{value:.1f}%', ha='center', va='center', fontsize=10, color='black')

    bottom = percentages[churn_status] if bottom is None else bottom + percentages[churn_status]

# Final touches
ax.set_title('Churn Percentage by Senior Citizen')
ax.set_ylabel('Percentage')
ax.legend(title='Churn')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\wadhw\AppData\Local\Temp\ipykernel_27160\4051856371.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   total_height = value if bottom is None else bottom[i] + value

# %% [markdown]
# comparitive a greater percentage of people in senior citizen category have churned

# %%
plt.figure(figsize=(9,4))
sns.histplot(x="tenure",data=df,bins=71, hue="Churn")
plt.show()

# %% [markdown]
# people who have used our sevices for a long time have stayed and people who have used our services for one or two month have churned

# %%
colors = ['skyblue', 'salmon']
ax=sns.countplot(x = "Contract",data=df,hue="Churn",color=colors[idx])
ax.bar_label(ax.containers[0])
plt.title("Churn by Contract")
plt.show()
# Out:
# C:\Users\wadhw\AppData\Local\Temp\ipykernel_27160\169186634.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   ax=sns.countplot(x = "Contract",data=df,hue="Churn",color=colors[idx])

# %% [markdown]
# peope who have month to month contract are likely to churn then from those who have one or two year of contract

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns to plot
cols = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Create subplots: adjust rows/cols as needed
n_cols = 3
n_rows = (len(cols) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 12))

# Flatten axes array for easy indexing
axes = axes.flatten()

for i, col in enumerate(cols):
    ax = axes[i]
    sns.countplot(data=df, x=col, ax=ax,hue=df["Churn"], order=df[col].value_counts().index)
    ax.set_title(f"{col} Count")
    ax.set_xlabel('')
    ax.set_ylabel('Count')
    ax.bar_label(ax.containers[0], fontsize=9)
    
# Turn off any extra axes if columns don't fill the grid
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Customers not using services like OnlineSecurity, TechSupport, and StreamingTV show higher churn rates.
#
# In almost every service, the "No internet service" group has zero or negligible churn, indicating internet access is crucial to customer retention.
#
# Fiber optic users have a higher churn compared to DSL users under InternetService.
#
# Overall, lack of value-added services (e.g., backup, protection, tech support) appears to be a strong indicator of customer churn.

# %%
plt.figure(figsize=(9,4))
colors = ['skyblue', 'salmon']
ax=sns.countplot(x = "PaymentMethod",data=df,hue="Churn",color=colors[idx])
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Churn by payment method")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\wadhw\AppData\Local\Temp\ipykernel_27160\2533275555.py:3: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   ax=sns.countplot(x = "PaymentMethod",data=df,hue="Churn",color=colors[idx])

# %% [markdown]
# customer is likely to churn when he is useing electroninc check fro payment method
